# %% [markdown]
# # Simulating whole-brain to study functional connectivity using Information Measures

# %% [markdown]
# ### Extracted from TVB-Optim github page:

# %%
# Imports
import jax
import jax.numpy as jnp
from tvboptim.experimental.network_dynamics import Network, solve, prepare
from tvboptim.experimental.network_dynamics.dynamics.tvb import ReducedWongWang
from tvboptim.experimental.network_dynamics.coupling import LinearCoupling, DelayedLinearCoupling
from tvboptim.experimental.network_dynamics.graph import DenseDelayGraph
from tvboptim.experimental.network_dynamics.noise import AdditiveNoise
from tvboptim.experimental.network_dynamics.solvers import Heun, BoundedSolver
from tvboptim.observations.tvb_monitors import Bold, SubSampling
from tvboptim.observations import compute_fc, fc_corr, rmse
from tvboptim.data import load_structural_connectivity, load_functional_connectivity
from tvboptim.types import Parameter
from tvboptim.optim import OptaxOptimizer
from tvboptim.optim.callbacks import DefaultPrintCallback, PrintParameterCallback
import optax

# Load example connectivity data (Desikan-Killiany 84-region parcellation)
# Structural connectivity: white matter connections derived from diffusion MRI
weights, lengths, labels = load_structural_connectivity("dk_average")
weights = weights / jnp.max(weights)  # Normalize connection weights
delays = lengths / 3.0  # Convert tract lengths (mm) to delays (ms) at 3 m/s conduction velocity

# Functional connectivity: empirical correlation patterns from resting-state fMRI
target_fc = load_functional_connectivity("dk_average")

# %%
# Build a brain network model with 84 regions
network = Network(
    dynamics=ReducedWongWang(),                     # Neural mass model (local dynamics)
    coupling={'delayed': DelayedLinearCoupling(     # How regions communicate
        incoming_states="S", G=0.5)},
    graph=DenseDelayGraph(weights, delays,          # Structural connectivity + delays
                          region_labels=labels),
    noise=AdditiveNoise(sigma=0.01,                 # Stochastic fluctuations
                        key=jax.random.key(42))
)

# Run 60-second simulation (1 ms time steps)
solver = BoundedSolver(Heun(), low = 0.0, high = 1.0) # Keep S between 0 and 1
result = solve(network, solver, t0=0.0, t1=60_000.0, dt=1.0)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 3))
# Get n colors from the viridis colormap
n = 10
colors = plt.cm.cividis_r(jnp.mean(result.ys[0:5000, 0, 0:n], axis = 0))
for i, color in enumerate(colors):
    ax.plot(result.ts[0:5000], result.ys[0:5000, 0, i], 
            linewidth=0.8, alpha=0.9, color=color)
ax.set_xlabel('Time (ms)')
ax.set_ylabel('S (activity)')
ax.set_title(f'Neural activity trajectories ({n} example regions)')
plt.tight_layout()
plt.show()

# %%
# Optimization workflow: fit coupling strength to match empirical functional connectivity

# Step 1: Prepare for optimization by converting the network to pure function + parameters
network.update_history(result)  # Use simulation result to initialize delay history
simulator, params = prepare(network, solver, t0=0.0, t1=60_000.0, dt=1.0)

# Step 2: Set up BOLD fMRI monitor
# Converts neural activity to BOLD signal via Balloon-Windkessel hemodynamic model
# Sampled every 720 ms (≈1.4 Hz) to match typical fMRI temporal resolution
bold_monitor = Bold(history=result, period=720.0, downsample=SubSampling(period=4.0))

# Step 3: Mark parameter for optimization
params.coupling.delayed.G = Parameter(0.5)

# Compute initial FC for comparison
def get_fc(params):
    """Helper to compute FC from simulation."""
    solution = simulator(params)
    bold = bold_monitor(solution)
    return compute_fc(bold)

fc_initial = get_fc(params)

# Step 4: Define loss and optimize
def loss(params):
    """Loss function using RMSE between predicted and empirical FC."""
    predicted_fc = get_fc(params)
    return rmse(predicted_fc, target_fc)

# Run optimization with Adam optimizer
opt = OptaxOptimizer(loss, optax.adam(learning_rate=0.03), callback=DefaultPrintCallback())
final_params, history = opt.run(params, max_steps=5)

# Compute final FC and print results
fc_final = get_fc(final_params)
print(f"\nOptimization complete: G={final_params.coupling.delayed.G:.3f}")
# Out:
# Step 0:    nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 32
#      28     return rmse(predicted_fc, target_fc)
#      29
#      30 # Run optimization with Adam optimizer
#      31 opt = OptaxOptimizer(loss, optax.adam(learning_rate=0.03), callback=DefaultPrintCallback())
# ---> 32 final_params, history = opt.run(params, max_steps=5)
#      33
#      34 # Compute final FC and print results
#      35 fc_final = get_fc(final_params)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/tvboptim/optim/optax.py:213, in OptaxOptimizer.run(self, state, max_steps, mode)
#     211 fitting_data = dict()  # store data during fitting
#     212 for i in range(max_steps):
# --> 213     diff_state, grads, opt_state, loss_value, aux_data = step(
#     214         diff_state, static_state, opt_state
#     215     )
#     216     # print(format_pytree_as_string(diff_state, hide_none=True, name="FreeState", show_array_values=True))
#     217     # print(format_pytree_as_string(diff_state, hide_none=True, name="FreeState", show_array_values=True))
#     218     # fitting_data.append(diff_state)
#     219     if self.callback is not None:
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/tvboptim/optim/optax.py:191, in OptaxOptimizer.run.<locals>.step(diff_state, static_state, opt_state)
#     189 def step(diff_state, static_state, opt_state):
#     190     # out = value_and_grad(_loss, argnums=0, has_aux=self.has_aux)(diff_state, static_state)
# --> 191     out = v_g_fun(diff_state, static_state)
#     192     (loss_value, aux_data), grads = out
#     194     # if self.has_aux:
#     195     #     (loss_value, aux_data), grads = out
#     196     # else:
#     197     #     loss_value, grads = out
#     198     #     aux_data = None
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/tvboptim/optim/optax.py:173, in OptaxOptimizer.run.<locals>.value_and_grad.<locals>._fun(*args, **kwargs)
#     172 def _fun(*args, **kwargs):
# --> 173     val, grads = vgf(*args, **kwargs)
#     174     return (val, None), grads
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/api.py:478, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     476   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     477 if not has_aux:
# --> 478   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     479 else:
#     480   ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/api.py:2134, in _vjp(fun, has_aux, *primals)
#    2132 if not has_aux:
#    2133   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2134   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    2135   out_tree = out_tree()
#    2136 else:
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/interpreters/ad.py:313, in vjp(traceable, primals, has_aux)
#     311 def vjp(traceable: lu.WrappedFun, primals, has_aux=False):
#     312   if not has_aux:
# --> 313     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     314   else:
#     315     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/interpreters/ad.py:287, in linearize(traceable, *primals, **kwargs)
#     285 has_aux = kwargs.pop('has_aux', False)
#     286 if config.use_direct_linearize.value:
# --> 287   return direct_linearize(traceable, primals, kwargs, has_aux=has_aux)
#     288 if not has_aux:
#     289   jvpfun = jvp(traceable)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/interpreters/ad.py:261, in direct_linearize(traceable, primals, kwargs, has_aux, tag)
#     256   aux_primals = [x.primal
#     257                  if isinstance(x, LinearizeTracer)
#     258                  and x._trace.tag is linearize_trace.tag
#     259                  else x for x in aux]
#     260 else:
# --> 261   ans = traceable.call_wrapped(*tracers)
#     262   aux = None
#     263 out_primals, out_tangents = unzip2(map(linearize_trace.to_primal_tangent_pair, ans))
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/api_util.py:292, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     290 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     291 assert next(fixed_args_, sentinel) is sentinel
# --> 292 return _fun(*args, **kwargs)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/linear_util.py:429, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     427 @transformation_with_aux2
#     428 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 429   ans = _fun(*args, **kwargs)
#     430   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     431   if _store:
#     432     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     433     # the bwd function in a custom_vjp
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/pjit.py:268, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     263 if config.no_tracing.value:
#     264   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     265                      "`jit`, but 'no_tracing' is set")
#     267 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 268  executable, pgle_profiler, const_args) = _python_pjit_helper(
#     269      fun, jit_info, *args, **kwargs)
#     271 maybe_fastpath_data = _get_fastpath_data(
#     272     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     273     jit_info.abstracted_axes, pgle_profiler,
#     274     const_args)
#     276 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/pjit.py:150, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     147   out_flat, compiled, profiler, const_args = _pjit_call_impl_python(
#     148       *args_flat, **p.params)
#     149 else:
# --> 150   out_flat = jit_p.bind(*args_flat, **p.params)
#     151   compiled = None
#     152   profiler = None
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/core.py:634, in Primitive.bind(self, *args, **params)
#     632 def bind(self, *args, **params):
#     633   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 634   return self._true_bind(*args, **params)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/core.py:650, in Primitive._true_bind(self, *args, **params)
#     648 trace_ctx.set_trace(eval_trace)
#     649 try:
# --> 650   return self.bind_with_trace(prev_trace, args, params)
#     651 finally:
#     652   trace_ctx.set_trace(prev_trace)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/core.py:662, in Primitive.bind_with_trace(self, trace, args, params)
#     660     with set_current_trace(trace):
#     661       return self.to_lojax(*args, **params)  # type: ignore
# --> 662   return trace.process_primitive(self, args, params)
#     663 trace.process_primitive(self, args, params)  # may raise lojax error
#     664 raise Exception(f"couldn't apply typeof to args: {args}")
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/interpreters/ad.py:900, in LinearizeTrace.process_primitive(self, primitive, args, params)
#     898 lin = primitive_linearizations.get(primitive, fallback)
#     899 with core.set_current_trace(self.parent_trace):
# --> 900   primal_out, tangent_nzs_out, residuals, linearized = lin(
#     901       tangent_nzs, *primals_in, **params)
#     902 with (core.set_current_trace(self.tangent_trace),
#     903       source_info_util.set_name_stack(self._name_stack_suffix())):
#     904   tangent_out = linearized(residuals, *tangents_in)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/pjit.py:2277, in _pjit_linearize(nzs, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *primals_in)
#    2274   return tuple(x for nz, x in zip(is_nz_l, l) if nz)
#    2276 assert len(in_shardings) == len(primal_jaxpr.in_avals)
# -> 2277 ans = jit_p.bind(*primals_in, jaxpr=primal_jaxpr,
#    2278                  in_shardings=in_shardings,
#    2279                  out_shardings=primal_out_shardings,
#    2280                  in_layouts=in_layouts,
#    2281                  out_layouts=primal_out_layouts,
#    2282                  donated_invars=donated_invars,
#    2283                  ctx_mesh=ctx_mesh,
#    2284                  name=name,
#    2285                  keep_unused=keep_unused,
#    2286                  inline=inline,
#    2287                  compiler_options_kvs=compiler_options_kvs)
#    2288 ans = subs_list(out_fwd, ans, ans)
#    2289 ans = subs_list(in_fwd, primals_in, ans)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/core.py:634, in Primitive.bind(self, *args, **params)
#     632 def bind(self, *args, **params):
#     633   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 634   return self._true_bind(*args, **params)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/core.py:650, in Primitive._true_bind(self, *args, **params)
#     648 trace_ctx.set_trace(eval_trace)
#     649 try:
# --> 650   return self.bind_with_trace(prev_trace, args, params)
#     651 finally:
#     652   trace_ctx.set_trace(prev_trace)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/core.py:662, in Primitive.bind_with_trace(self, trace, args, params)
#     660     with set_current_trace(trace):
#     661       return self.to_lojax(*args, **params)  # type: ignore
# --> 662   return trace.process_primitive(self, args, params)
#     663 trace.process_primitive(self, args, params)  # may raise lojax error
#     664 raise Exception(f"couldn't apply typeof to args: {args}")
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/core.py:1189, in EvalTrace.process_primitive(self, primitive, args, params)
#    1187 args = map(full_lower, args)
#    1188 check_eval_args(args)
# -> 1189 return primitive.impl(*args, **params)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/pjit.py:1829, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1821 donated_argnums = tuple(i for i, d in enumerate(donated_invars) if d)
#    1822 cache_key = pxla.JitGlobalCppCacheKeys(
#    1823     donate_argnums=donated_argnums, donate_argnames=None,
#    1824     device=None, backend=None,
#    (...)   1827     in_layouts_treedef=None, in_layouts_leaves=in_layouts,
#    1828     out_layouts_treedef=None, out_layouts_leaves=out_layouts)
# -> 1829 return xc._xla.pjit(
#    1830     name, f, call_impl_cache_miss, [], [], cache_key,
#    1831     tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1832     _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/pjit.py:1805, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1801 def call_impl_cache_miss(*args_, **kwargs_):
#    1802   # args_ do not include the const args
#    1803   # See https://docs.jax.dev/en/latest/internals/constants.html.
#    1804   # TODO(necula): remove num_const_args when fixing the C++ path
# -> 1805   out_flat, compiled, pgle_profiler, const_args = _pjit_call_impl_python(
#    1806       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1807       out_shardings=out_shardings, in_layouts=in_layouts,
#    1808       out_layouts=out_layouts, donated_invars=donated_invars,
#    1809       ctx_mesh=ctx_mesh, name=name, keep_unused=keep_unused,
#    1810       inline=inline, compiler_options_kvs=compiler_options_kvs)
#    1811   fastpath_data = _get_fastpath_data(
#    1812       compiled, tree_structure(out_flat), args, out_flat,
#    1813       jaxpr.effects, jaxpr.consts, None, pgle_profiler,
#    1814       const_args)
#    1815   return out_flat, fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/pjit.py:1780, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1772     fingerprint = fingerprint.hex()
#    1773   distributed_debug_log(("Running pjit'd function", name),
#    1774                         ("in_shardings", in_shardings),
#    1775                         ("out_shardings", out_shardings),
#    (...)   1778                         ("abstract args", map(core.abstractify, args)),
#    1779                         ("fingerprint", fingerprint))
# -> 1780 return (compiled.unsafe_call(*computation.const_args, *args),
#    1781         compiled, pgle_profiler, computation.const_args)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/profiler.py:364, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     361 @wraps(func)
#     362 def wrapper(*args, **kwargs):
#     363   with TraceAnnotation(name, **decorator_kwargs):
# --> 364     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/phiid/lib/python3.14/site-packages/jax/_src/interpreters/pxla.py:1379, in ExecuteReplicated.__call__(self, *args)
#    1377   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1378 else:
# -> 1379   results = self.xla_executable.execute_sharded(input_bufs)
#    1381 if dispatch.needs_check_special():
#    1382   out_arrays = results.disassemble_into_single_device_arrays()
#
# KeyboardInterrupt:

# %%
# Compute correlations
corr_initial = fc_corr(fc_initial, target_fc)
corr_final = fc_corr(fc_final, target_fc)

fig, axes = plt.subplots(1, 3, figsize=(12, 3.5))

# Initial FC
im0 = axes[0].imshow(fc_initial, cmap='cividis', vmin=0, vmax=1)
axes[0].set_title(f'Initial FC (G=0.5, r={corr_initial:.3f})')
axes[0].set_xlabel('Region')
axes[0].set_ylabel('Region')
plt.colorbar(im0, ax=axes[0], fraction=0.046)

# Final FC
im1 = axes[1].imshow(fc_final, cmap='cividis', vmin=0, vmax=1)
axes[1].set_title(f'Optimized FC (G={final_params.coupling.delayed.G:.2f}, r={corr_final:.3f})')
axes[1].set_xlabel('Region')
axes[1].set_ylabel('Region')
plt.colorbar(im1, ax=axes[1], fraction=0.046)

# Target FC
im2 = axes[2].imshow(target_fc, cmap='cividis', vmin=0, vmax=1)
axes[2].set_title('Empirical FC')
axes[2].set_xlabel('Region')
axes[2].set_ylabel('Region')
plt.colorbar(im2, ax=axes[2], fraction=0.046)

plt.tight_layout()
plt.show()

# Print correlation improvements
print(f"FC correlation improvement: {corr_initial:.3f} → {corr_final:.3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Compute correlations
#       2 corr_initial = fc_corr(fc_initial, target_fc)
# ----> 3 corr_final = fc_corr(fc_final, target_fc)
#       4
#       5 fig, axes = plt.subplots(1, 3, figsize=(12, 3.5))
#       6
#
# NameError: name 'fc_final' is not defined
